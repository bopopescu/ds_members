# %%
# %run plot_good_customer.py

# %%
plot_floating(df, 'med_fam_income')

# %%
plot_floating(df, 'married_couples__density')

# %%
df.dtypes
# Out:
# user_id                                  int64
# avg_keep_rate                          float64
# num_boxes                              float64
# email                                   object
# state                                   object
# is_member                                 bool
# created_at                      datetime64[ns]
# became_member_at                datetime64[ns]
# service_fee                            float64
# service_fee_enabled                       bool
# zipcode                                 object
# num_boys                                 int64
# num_girls                                int64
# num_kids                                 int64
# is_referred                               bool
# first_click_source                      object
# device                                  object
# OS                                      object
# is_good_customer                          bool
# households                             float64
# ...

# %%
plot_floating(df, 'females_density')

# %%
plot_floating(df, 'minutes_to_convert')

# %%
plot_floating(df, 'employed_civil_percent')

# %%
plot_floating(df, 'members_in_zip')

# %%
plot_integer(df, 'service_fee')

# %%
plot_categorical(df, 'first_click_source')

# %%
df.dtypes
# Out:
# user_id                                  int64
# avg_keep_rate                          float64
# num_boxes                              float64
# email                                   object
# state                                   object
# is_member                                 bool
# created_at                      datetime64[ns]
# became_member_at                datetime64[ns]
# service_fee                            float64
# service_fee_enabled                       bool
# zipcode                                 object
# num_boys                                 int64
# num_girls                                int64
# num_kids                                 int64
# is_referred                               bool
# first_click_source                      object
# device                                  object
# OS                                      object
# is_good_customer                          bool
# households                             float64
# ...

# %%
t = 'emilyagarrett@gmail.com'

# %%
import re

# %%
r = re.search(r'[\w+]@[\w+\.\w]', t)

# %%
t.split('@')[1]
# Out:
# 'gmail.com'

# %%
df['domain'] = df['email'].apply(lambda x: x.split('@')[1])

# %%
plot_categorical(df, 'domain')

# %%
df.dtypes
# Out:
# user_id                                  int64
# avg_keep_rate                          float64
# num_boxes                              float64
# email                                   object
# state                                   object
# is_member                                 bool
# created_at                      datetime64[ns]
# became_member_at                datetime64[ns]
# service_fee                            float64
# service_fee_enabled                       bool
# zipcode                                 object
# num_boys                                 int64
# num_girls                                int64
# num_kids                                 int64
# is_referred                               bool
# first_click_source                      object
# device                                  object
# OS                                      object
# is_good_customer                          bool
# households                             float64
# ...
